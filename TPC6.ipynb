# %% [markdown]
# __Idenficador:__ TPC6
# __Título do Trabalho:__ Trabalhar com amostras gráficas
# __Data de ínicio:__ 2021-11-15
# __Data do Fim:__ 2021-11-21
# __Supervisor:__ José Carlos Ramalho
# __Autor:__ Luís Manuel Mendonça Gonçalves A95637
#
#
# __Resumo:__
# Neste trabalho foi pedido que fosse desenvolvido as capacidades de trabalhar com as potencialidades gráficas do oython atraves da extensão _matplotlib_.
# Nestes exercicios foram pedidos para fazer graficos simples tais como fazer quadrados de lado definido, desenhar n quadrados de lado um maior que o outro e também trabalhar gráficamente com polínomios

# %%
import matplotlib.pyplot as plt
 #Quadrado de lado 5
plt.plot([-2.5,2.5,2.5,-2.5,-2.5],[2.5,2.5,-2.5,-2.5,2.5])

plt.xlim(-3, 3)
plt.ylim(-3, 3)
# Out:
# (-3.0, 3.0)

# %%
#desenha n quadrados centrados na origem com lados 1..10
n=int(input("Qual o número de quadrados? \n"))
for i in range (n+1):
    plt.plot([-1*i,1*i,1*i,-1*i,-1*i],[1*i,1*i,-1*i,-1*i,1*i])
plt.xlim(-n-1, n+1)
plt.ylim(-n-1, n+1)
# Out:
# (-6.0, 6.0)

# %%
import matplotlib.pyplot as plt
import Polinomio as pol
#representa graficamente os seguintes polinómios
#2x - 5
#x^2 - 7
#x^3 - 2x^2 + 1
plt.xlim(-1, 100)
plt.ylim(-10,200)
p1=[(2,1),(-5,0)]
p2=[(1,2),(-7,0)]
p3=[(1,3),(-2,2),(1,0)]

a=[]
b=[]
for i in range(101):
    a.append(i)
    b.append(pol.calcPolinomio(p1,i))
a2=[]
b2=[]
for i in range(101):
    a2.append(i)
    b2.append(pol.calcPolinomio(p2,i))
a3=[]
b3=[]
for i in range(101):
    a3.append(i)
    b3.append(pol.calcPolinomio(p3,i))
print(b3)    

plt.plot(a,b)
plt.plot(a2,b2)
plt.plot(a3,b3)
# Out:
# [1, 0, 1, 10, 33, 76, 145, 246, 385, 568, 801, 1090, 1441, 1860, 2353, 2926, 3585, 4336, 5185, 6138, 7201, 8380, 9681, 11110, 12673, 14376, 16225, 18226, 20385, 22708, 25201, 27870, 30721, 33760, 36993, 40426, 44065, 47916, 51985, 56278, 60801, 65560, 70561, 75810, 81313, 87076, 93105, 99406, 105985, 112848, 120001, 127450, 135201, 143260, 151633, 160326, 169345, 178696, 188385, 198418, 208801, 219540, 230641, 242110, 253953, 266176, 278785, 291786, 305185, 318988, 333201, 347830, 362881, 378360, 394273, 410626, 427425, 444676, 462385, 480558, 499201, 518320, 537921, 558010, 578593, 599676, 621265, 643366, 665985, 689128, 712801, 737010, 761761, 787060, 812913, 839326, 866305, 893856, 921985, 950698, 980001]
